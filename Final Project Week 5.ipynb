# %% [markdown]
# # The Battle of Neighborhoods (Week 2) - David Wilson

# %% [markdown]
# Introduction and definition of the scope of the problem
#
# Our target audience and stakeholders are companies and individuals who wish to open new restaurant premises on the city of Houston’s popular Energy Corridor.  However that is not a straightforwards process, for reasons I will next explain.  The pitfalls are mainly competition, cost of operating a business, cultural differences that exist in some areas, and the demographic makeup of some localities.  Thus the clients require an analysis of the local neighborhoods to understand the scope of the issues.  Some types of restaurants are better suited to particular areas.
#
# The population of the City of Houston, Texas is an estimated 2,099,451.  Houston is a cosmopolitan city with a broad mixture of Americans and immigrants from other countries.  The demographic makeup of the people in the city are of mainly White, African Americans, Hispanic or Latino, and Native Americans.  Naturally there is much choice of restaurants, serving both Domestic and foreign foods, and even the popular indigenous Tex-Mex varieties which are found only in Texas.
#
# Houston Demographics
# White: 50.5% (25.6% non-Hispanic)
# Black or African American: 23.7%
# American Indian: 0.7%
# Asian: 6%
# Pacific Islander: 0.1%
# ther race: 15.2% (0.2% non-Hispanic)
# Two or more races: 3.3%
# Hispanic of any race: 43.8%
# Jan 10, 2019
#
# Since Houston is such a multicultural and eclectic hub, with a large workforce available, the city offers many business opportunities which groups of investors can exploit.  The downside is, that since there are many restaurants there already, hence the competition for customers is considerable.  Property in the Energy Corridor area is also expensive and suffers from being heavily taxed.  The cost of trading in Houston, therefore requires to be thoroughly analyzed and considered before any new company can be opened.  In this analysis we will attempt to find the best location for the new business, by examining what already exists in the chosen area.  In particular we will be looking at the Energy Corridor area of the city.

# %% [markdown]
# Data Description
#
# The data that will be used to solve the problem:
# We will be using Foursquare and geopy data to map top the top venues within the location of Houstons Energy Corridor
# to indicate what venues already exist in this popular area. We will create a map of the area covering about 5000m.

# %% [markdown]
# Methodology
#
# The methodology we have used was to utilize Foursquare to analyse the chosen neighborhood and create a breakdown of businesses types and numbers in the chosen area.  The idea behind this, is that if we know the numbers and types of restaurants and franchises already present there, it will allow us to decide on which type of new restaurant would be the most welcome with the least amount of competition in that type of food.

# %% [markdown]
# Discussion
#
# It was found that some types of restuarant and francise where far more common than others.
#
# In particular:
# Starbucks        4
# Smashburger      2
# Chick-fil-A      2
# SUBWAY           2
#
# Others were less clear, since there are several Mexican or Tex-Mex resturants in the area which the data makes harder to count.  In the main however, business showed a good spread of uniqueness, and where mostly one of a kind in that area.

# %% [markdown]
# Conclusion
#
# The area is suited to opening an up-market restaurant, main competition comes from the Mexican resturants and Fast Food.

# %%
import numpy as np # library to handle data in a vectorized manner
import time
import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files
import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values
# !conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Fetching package metadata .............
# Solving package specifications: .
#
# # All requested packages already installed.
# # packages in environment at /opt/conda/envs/DSX-Python35:
# #
# folium                    0.5.0                      py_0    conda-forge
# Libraries imported.

# %% [markdown]
# Neighborhood Candidates
# We will be creating gepgraphic coordinates for centroids of our candidate neighborhoods.
# First we'll find the latitude & longitude of Houston's popular Energy Corridor a likely
# contender for siting the new restaurant.

# %%
# Find the geographical coordinates of The Energy Corridor, Houston, TX
address = 'energy corridor, Houston, texas'

geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of the Energy Corridor, Houston, TX are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of the Energy Corridor, Houston, TX are 29.7862905, -95.6581257.

# %%
city_center = [latitude, longitude]
print('Coordinate of {}: {}'.format(address, city_center))
city_center
# Out:
# Coordinate of energy corridor, Houston, texas: [29.7862905, -95.6581257]
# [29.7862905, -95.6581257]

# %%
neighborhood_latitude=29.7862905
neighborhood_longitude=-95.392313

# %%
#!pip install folium

import folium

# %%
CLIENT_ID = 'SXUPV3IPG1VRYAIEKCEIIXE4GR1ZGSUNIPTKXB5C02I514K0' # my Foursquare ID
CLIENT_SECRET = 'LC1PKVJZGO5RSMWKGYQL5JGSYC1FT14SW1OZM11FGB51GLBB' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
radius = 500
LIMIT = 100

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: SXUPV3IPG1VRYAIEKCEIIXE4GR1ZGSUNIPTKXB5C02I514K0
# CLIENT_SECRET:LC1PKVJZGO5RSMWKGYQL5JGSYC1FT14SW1OZM11FGB51GLBB

# %% [markdown]
# Get the top 100 venues that are near Houston's Energy Corridor. within a radius of 5000 meters

# %%
LIMIT = 100 # limit of number of venues returned by Foursquare API

radius = 5000 # define radius

# create URL
url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude, 
    longitude, 
    radius, 
    LIMIT)
url # display URL
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=SXUPV3IPG1VRYAIEKCEIIXE4GR1ZGSUNIPTKXB5C02I514K0&client_secret=LC1PKVJZGO5RSMWKGYQL5JGSYC1FT14SW1OZM11FGB51GLBB&v=20180605&ll=29.7862905,-95.6581257&radius=5000&limit=100'

# %% [markdown]
# Send the GET request and examine the resutls

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5c8b80bb9fb6b753bc6b10f7'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-505363dfe4b09a662ca2487f-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/golfcourse_',
#           'suffix': '.png'},
#          'id': '58daa1558bbb0b01f18ec1b0',
#          'name': 'Golf Driving Range',
#          'pluralName': 'Golf Driving Ranges',
#          'primary': True,
#          'shortName': 'Golf Driving Range'}],
#        'id': '505363dfe4b09a662ca2487f',
#        'location': {'address': '1030 Memorial Brook Blvd',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 781,
#         'formattedAddress': ['1030 Memorial Brook Blvd',
#          'Houston, TX 77084',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.786743399909664,
#           'lng': -95.65005049109459}],
#         'lat': 29.786743399909664,
#         'lng': -95.65005049109459,
#         'postalCode': '77084',
#         'state': 'TX'},
#        'name': 'Topgolf',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '78617132'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b1971b0f964a5206edd23e3-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '4b1971b0f964a5206edd23e3',
#        'location': {'address': '1029 Highway 6 N',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1219,
#         'formattedAddress': ['1029 Highway 6 N',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7868891115356,
#           'lng': -95.64552536741392}],
#         'lat': 29.7868891115356,
#         'lng': -95.64552536741392,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': "Brother's Pizzeria",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4abea415f964a520048f20e3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '4abea415f964a520048f20e3',
#        'location': {'address': '14656 Grisby Rd',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1456,
#         'formattedAddress': ['14656 Grisby Rd',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.782843540365803,
#           'lng': -95.64357914092952}],
#         'lat': 29.782843540365803,
#         'lng': -95.64357914092952,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': "Watson's House of Ale's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b3a57c2f964a520226525e3-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'id': '4b3a57c2f964a520226525e3',
#        'location': {'address': '14555 Grisby Rd',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'near I-10',
#         'distance': 1499,
#         'formattedAddress': ['14555 Grisby Rd (near I-10)',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.782903283989956,
#           'lng': -95.64310002742009}],
#         'lat': 29.782903283989956,
#         'lng': -95.64310002742009,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': 'Lupe Tortilla Mexican Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b2ee89ef964a52025e824e3-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d145941735',
#          'name': 'Chinese Restaurant',
#          'pluralName': 'Chinese Restaurants',
#          'primary': True,
#          'shortName': 'Chinese'}],
#        'id': '4b2ee89ef964a52025e824e3',
#        'location': {'address': '14525 Katy Fwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1539,
#         'formattedAddress': ['14525 Katy Fwy',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.783943708205165,
#           'lng': -95.64241913308045}],
#         'lat': 29.783943708205165,
#         'lng': -95.64241913308045,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': 'North China Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d29128d55a8b60c4a94d3c0-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/salad_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1bd941735',
#          'name': 'Salad Place',
#          'pluralName': 'Salad Places',
#          'primary': True,
#          'shortName': 'Salad'}],
#        'id': '4d29128d55a8b60c4a94d3c0',
#        'location': {'address': '14515 Katy Fwy #100',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1581,
#         'formattedAddress': ['14515 Katy Fwy #100',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.783908119441314,
#           'lng': -95.64199169546939}],
#         'lat': 29.783908119441314,
#         'lng': -95.64199169546939,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': 'Salata',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-54665c10498e676b5e2e2394-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/sportsbar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11d941735',
#          'name': 'Sports Bar',
#          'pluralName': 'Sports Bars',
#          'primary': True,
#          'shortName': 'Sports Bar'}],
#        'id': '54665c10498e676b5e2e2394',
#        'location': {'address': '1010 Highway 6 N',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1355,
#         'formattedAddress': ['1010 Highway 6 N',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.78686463109469,
#           'lng': -95.64411049858384}],
#         'lat': 29.78686463109469,
#         'lng': -95.64411049858384,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': "Christian's Tailgate Bar & Grill",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-56bc3048498e9cead1872510-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '56bc3048498e9cead1872510',
#        'location': {'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 118,
#         'formattedAddress': ['Houston, TX 77084', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.78730627504188,
#           'lng': -95.65850599383879}],
#         'lat': 29.78730627504188,
#         'lng': -95.65850599383879,
#         'postalCode': '77084',
#         'state': 'TX'},
#        'name': 'SpringHill Suites by Marriott',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d839bcd61676dcbd2795fe4-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4d839bcd61676dcbd2795fe4',
#        'location': {'address': '1029 Highway 6 N #200',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1221,
#         'formattedAddress': ['1029 Highway 6 N #200',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.78694824085376,
#           'lng': -95.64550589190347}],
#         'lat': 29.78694824085376,
#         'lng': -95.64550589190347,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': 'Annam Indian Cuisine',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc8aca1c1c6eee1b1d4fd92-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4bc8aca1c1c6eee1b1d4fd92',
#        'location': {'address': '15111 Katy Fwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 787,
#         'formattedAddress': ['15111 Katy Fwy',
#          'Houston, TX 77094',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.783946551031512,
#           'lng': -95.65043667202758}],
#         'lat': 29.783946551031512,
#         'lng': -95.65043667202758,
#         'postalCode': '77094',
#         'state': 'TX'},
#        'name': 'Fairfield Inn & Suites Houston I-10 West/Energy Corridor',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '129871293'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bbb6930b35776b070eecb01-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4bbb6930b35776b070eecb01',
#        'location': {'address': '16802 Barker Springs Rd',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1667,
#         'formattedAddress': ['16802 Barker Springs Rd',
#          'Houston, TX 77084',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.786056576797698,
#           'lng': -95.6753801460272}],
#         'lat': 29.786056576797698,
#         'lng': -95.6753801460272,
#         'postalCode': '77084',
#         'state': 'TX'},
#        'name': "Freddy's Cafe",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51e9ef4c498eca0bd1111b70-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/sushi_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d2941735',
#          'name': 'Sushi Restaurant',
#          'pluralName': 'Sushi Restaurants',
#          'primary': True,
#          'shortName': 'Sushi'}],
#        'id': '51e9ef4c498eca0bd1111b70',
#        'location': {'address': '1029 Highway 6 N',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1243,
#         'formattedAddress': ['1029 Highway 6 N',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.78757348298705,
#           'lng': -95.64533906881549}],
#         'lat': 29.78757348298705,
#         'lng': -95.64533906881549,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': 'Umami Sushi',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc8ea21937ca593cfc0a492-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '4bc8ea21937ca593cfc0a492',
#        'location': {'address': '735 Highway 6 S',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1762,
#         'formattedAddress': ['735 Highway 6 S',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.776409336761137,
#           'lng': -95.64387066223016}],
#         'lat': 29.776409336761137,
#         'lng': -95.64387066223016,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': 'Dairy Queen',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ba949e6f964a520bf1b3ae3-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4ba949e6f964a520bf1b3ae3',
#        'location': {'address': '15200 Memorial Dr',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'Memorial Mews Dr',
#         'distance': 3476,
#         'formattedAddress': ['15200 Memorial Dr (Memorial Mews Dr)',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.779137928592483,
#           'lng': -95.62309629230401}],
#         'lat': 29.779137928592483,
#         'lng': -95.62309629230401,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': 'Terry Hershey Park',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5176bfdce4b012885594d6eb-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/sports_outdoors_',
#           'suffix': '.png'},
#          'id': '4f4528bc4b90abdf24c9de85',
#          'name': 'Athletics & Sports',
#          'pluralName': 'Athletics & Sports',
#          'primary': True,
#          'shortName': 'Athletics & Sports'}],
#        'id': '5176bfdce4b012885594d6eb',
#        'location': {'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 3310,
#         'formattedAddress': ['Houston, TX', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.780617671538966,
#           'lng': -95.6244869854214}],
#         'lat': 29.780617671538966,
#         'lng': -95.6244869854214,
#         'state': 'TX'},
#        'name': 'Terry Hershey Bike Trail',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ac6c9ebf964a52047b620e3-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/dogrun_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e5941735',
#          'name': 'Dog Run',
#          'pluralName': 'Dog Runs',
#          'primary': True,
#          'shortName': 'Dog Run'}],
#        'id': '4ac6c9ebf964a52047b620e3',
#        'location': {'address': '3201 SH 6',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'at Groeschke Rd.',
#         'distance': 3626,
#         'formattedAddress': ['3201 SH 6 (at Groeschke Rd.)',
#          'Houston, TX 77084',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.817540063579983,
#           'lng': -95.6475126561986}],
#         'lat': 29.817540063579983,
#         'lng': -95.6475126561986,
#         'postalCode': '77084',
#         'state': 'TX'},
#        'name': 'Bill Archer Dog Park',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-510ff665e4b0c9edea6152e9-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'delivery': {'id': '550365',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/tonys-mexican-restaurant-17790-katy-fwy-houston/550365?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=550365'},
#        'id': '510ff665e4b0c9edea6152e9',
#        'location': {'address': '17790 Katy Freeway',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'I-10',
#         'distance': 2534,
#         'formattedAddress': ['17790 Katy Freeway (I-10)',
#          'Houston, TX 77094',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.786048846373184,
#           'lng': -95.68435336355338}],
#         'lat': 29.786048846373184,
#         'lng': -95.68435336355338,
#         'postalCode': '77094',
#         'state': 'TX'},
#        'name': "Tony's Mexican Restaurant",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b99b435f964a520188d35e3-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4b99b435f964a520188d35e3',
#        'location': {'address': '803 Highway 6 S',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1872,
#         'formattedAddress': ['803 Highway 6 S',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.775286,
#           'lng': -95.64347}],
#         'lat': 29.775286,
#         'lng': -95.64347,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': 'Starbucks',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bf54ece6a31d13a65b2962e-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '4bf54ece6a31d13a65b2962e',
#        'location': {'address': '15730 Park Row',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'Park Ten',
#         'distance': 341,
#         'formattedAddress': ['15730 Park Row (Park Ten)',
#          'Houston, TX 77084',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.78935977549349,
#           'lng': -95.65800693180718}],
#         'lat': 29.78935977549349,
#         'lng': -95.65800693180718,
#         'postalCode': '77084',
#         'state': 'TX'},
#        'name': 'Kolache Factory - Park Row',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cf0356088de3704be116a2b-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4cf0356088de3704be116a2b',
#        'location': {'address': '15225 Katy Fwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 707,
#         'formattedAddress': ['15225 Katy Fwy',
#          'Houston, TX 77094',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.783666421523712,
#           'lng': -95.6514612709472}],
#         'lat': 29.783666421523712,
#         'lng': -95.6514612709472,
#         'postalCode': '77094',
#         'state': 'TX'},
#        'name': 'LaQuinta Inns & Suites',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc7701f6501c9b6366f3e29-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/salon_barber_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110951735',
#          'name': 'Salon / Barbershop',
#          'pluralName': 'Salons / Barbershops',
#          'primary': True,
#          'shortName': 'Salon / Barbershop'}],
#        'id': '4bc7701f6501c9b6366f3e29',
#        'location': {'address': '1127 Eldridge Pkwy Ste 1008',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 3950,
#         'formattedAddress': ['1127 Eldridge Pkwy Ste 1008',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.767433394168936,
#           'lng': -95.6234906383084}],
#         'lat': 29.767433394168936,
#         'lng': -95.6234906383084,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': "Josephine's Day Spa and Salon (Energy Corridor)",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c9b494beaa5a143724ed3e4-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4c9b494beaa5a143724ed3e4',
#        'location': {'address': '1127 Eldridge Pkwy #100',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 3966,
#         'formattedAddress': ['1127 Eldridge Pkwy #100',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.76773892912626,
#           'lng': -95.62307808621159}],
#         'lat': 29.76773892912626,
#         'lng': -95.62307808621159,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'Beans Cafe',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '81116475'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5245c87511d21404894b86ee-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'id': '5245c87511d21404894b86ee',
#        'location': {'address': '1120 Eldridge Pkwy Ste 100',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'Enclave Pkwy & Eldridge Pkwy South',
#         'distance': 3843,
#         'formattedAddress': ['1120 Eldridge Pkwy Ste 100 (Enclave Pkwy & Eldridge Pkwy South)',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.768375472138295,
#           'lng': -95.62411770080138}],
#         'lat': 29.768375472138295,
#         'lng': -95.62411770080138,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'Chipotle Mexican Grill',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e37efac8877541e90e9e3d9-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b41',
#          'name': 'Smoothie Shop',
#          'pluralName': 'Smoothie Shops',
#          'primary': True,
#          'shortName': 'Smoothie Shop'}],
#        'id': '4e37efac8877541e90e9e3d9',
#        'location': {'address': '118 Weslayan',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'Richmond',
#         'distance': 1344,
#         'formattedAddress': ['118 Weslayan (Richmond)',
#          'Houston, TX 77027',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.785112612558653,
#           'lng': -95.67197507962273}],
#         'lat': 29.785112612558653,
#         'lng': -95.67197507962273,
#         'postalCode': '77027',
#         'state': 'TX'},
#        'name': 'Smoothie King',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ba3b743f964a520a95738e3-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/asian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d142941735',
#          'name': 'Asian Restaurant',
#          'pluralName': 'Asian Restaurants',
#          'primary': True,
#          'shortName': 'Asian'}],
#        'id': '4ba3b743f964a520a95738e3',
#        'location': {'address': '1396 Eldridge Pkwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4215,
#         'formattedAddress': ['1396 Eldridge Pkwy',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.760671447604746,
#           'lng': -95.6259994414167}],
#         'lat': 29.760671447604746,
#         'lng': -95.6259994414167,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'Rattan Pan-Asian Bistro',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-557f58a5498e38aa640e5918-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '557f58a5498e38aa640e5918',
#        'location': {'address': '19303 Katy Fwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4685,
#         'formattedAddress': ['19303 Katy Fwy',
#          'Houston, TX 77094',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.78435,
#           'lng': -95.706576}],
#         'lat': 29.78435,
#         'lng': -95.706576,
#         'postalCode': '77094',
#         'state': 'TX'},
#        'name': 'Chick-fil-A',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5137c305e4b068699e9471a6-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'primary': True,
#          'shortName': 'French'}],
#        'delivery': {'id': '1104397',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/la-madeleine-1560-eldridge-pkwy-ste-190-houston/1104397?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=1104397'},
#        'id': '5137c305e4b068699e9471a6',
#        'location': {'address': '1560 Eldridge Pkwy Ste 190',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4447,
#         'formattedAddress': ['1560 Eldridge Pkwy Ste 190',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.756069,
#           'lng': -95.628015}],
#         'lat': 29.756069,
#         'lng': -95.628015,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'la Madeleine French Bakery & Café Parkway Village',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c52fc13b6dabe9a9cc81214-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'primary': True,
#          'shortName': 'Vietnamese'}],
#        'id': '4c52fc13b6dabe9a9cc81214',
#        'location': {'address': 'I-10 West',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'Barker Cypress',
#         'distance': 2585,
#         'formattedAddress': ['I-10 West (Barker Cypress)',
#          'Houston, TX',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.786167062816904,
#           'lng': -95.6848832486909}],
#         'lat': 29.786167062816904,
#         'lng': -95.6848832486909,
#         'state': 'TX'},
#        'name': 'Pho Tan An',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5892247846563a4f59e493f9-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d17a941735',
#          'name': 'Cajun / Creole Restaurant',
#          'pluralName': 'Cajun / Creole Restaurants',
#          'primary': True,
#          'shortName': 'Cajun / Creole'}],
#        'id': '5892247846563a4f59e493f9',
#        'location': {'address': '1275 Eldridge Pkwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4084,
#         'formattedAddress': ['1275 Eldridge Pkwy',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.76381675901417,
#           'lng': -95.62471191182222}],
#         'lat': 29.76381675901417,
#         'lng': -95.62471191182222,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': "BB's Tex-Orleans Cooking!",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d1247b1d0fda093a8d5aa57-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d17a941735',
#          'name': 'Cajun / Creole Restaurant',
#          'pluralName': 'Cajun / Creole Restaurants',
#          'primary': True,
#          'shortName': 'Cajun / Creole'}],
#        'id': '4d1247b1d0fda093a8d5aa57',
#        'location': {'address': '1935 Highway 6 S',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4406,
#         'formattedAddress': ['1935 Highway 6 S',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.748708956083473,
#           'lng': -95.64381935219846}],
#         'lat': 29.748708956083473,
#         'lng': -95.64381935219846,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'LA Fisherman',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52e08ef8498e46db64dfbf03-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/fastfood_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16e941735',
#          'name': 'Fast Food Restaurant',
#          'pluralName': 'Fast Food Restaurants',
#          'primary': True,
#          'shortName': 'Fast Food'}],
#        'id': '52e08ef8498e46db64dfbf03',
#        'location': {'address': '13412 Briar Forest Dr',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4556,
#         'formattedAddress': ['13412 Briar Forest Dr',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.755845,
#           'lng': -95.626613}],
#         'lat': 29.755845,
#         'lng': -95.626613,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'Chick-fil-A',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b12ce5ff964a5207c8e23e3-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/newamerican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d157941735',
#          'name': 'New American Restaurant',
#          'pluralName': 'New American Restaurants',
#          'primary': True,
#          'shortName': 'New American'}],
#        'id': '4b12ce5ff964a5207c8e23e3',
#        'location': {'address': '15455 Memorial Dr',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 3042,
#         'formattedAddress': ['15455 Memorial Dr',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.779517927538365,
#           'lng': -95.62761899610508}],
#         'lat': 29.779517927538365,
#         'lng': -95.62761899610508,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': 'Cafe Benedicte',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '509861848'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ed7a26202d57802e6061655-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'primary': True,
#          'shortName': 'Park'}],
#        'id': '4ed7a26202d57802e6061655',
#        'location': {'address': '18203 Groeschke Rd',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 3286,
#         'formattedAddress': ['18203 Groeschke Rd',
#          'Houston, TX 77084',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.81185823922502,
#           'lng': -95.6751319023751}],
#         'lat': 29.81185823922502,
#         'lng': -95.6751319023751,
#         'postalCode': '77084',
#         'state': 'TX'},
#        'name': 'Cullen Park Phase IV',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51c0b720498e0b356e17eb6b-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '51c0b720498e0b356e17eb6b',
#        'location': {'address': '19235 Katy Freeway',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4572,
#         'formattedAddress': ['19235 Katy Freeway',
#          'Houston, TX 77094',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.7841919,
#           'lng': -95.70539666}],
#         'lat': 29.7841919,
#         'lng': -95.70539666,
#         'postalCode': '77094',
#         'state': 'TX'},
#        'name': 'Starbucks',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-53dbc67a498e5585a2968584-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'primary': True,
#          'shortName': 'Vietnamese'}],
#        'id': '53dbc67a498e5585a2968584',
#        'location': {'address': '14741 Memorial Dr',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4932,
#         'formattedAddress': ['14741 Memorial Dr',
#          'Houston, TX 77079',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.770176323965163,
#           'lng': -95.61056596649497}],
#         'lat': 29.770176323965163,
#         'lng': -95.61056596649497,
#         'postalCode': '77079',
#         'state': 'TX'},
#        'name': 'Pho & Crab Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-52018310498e62046853e758-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cajun_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d17a941735',
#          'name': 'Cajun / Creole Restaurant',
#          'pluralName': 'Cajun / Creole Restaurants',
#          'primary': True,
#          'shortName': 'Cajun / Creole'}],
#        'id': '52018310498e62046853e758',
#        'location': {'address': '1420 Barker Cypress Rd',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'Park Row',
#         'distance': 2865,
#         'formattedAddress': ['1420 Barker Cypress Rd (Park Row)',
#          'Houston, TX 77084',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.788353589163115,
#           'lng': -95.68769101482287}],
#         'lat': 29.788353589163115,
#         'lng': -95.68769101482287,
#         'postalCode': '77084',
#         'state': 'TX'},
#        'name': "Popeye's Louisiana Kitchen",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-504e277ae4b06b3022818ccc-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/vietnamese_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14a941735',
#          'name': 'Vietnamese Restaurant',
#          'pluralName': 'Vietnamese Restaurants',
#          'primary': True,
#          'shortName': 'Vietnamese'}],
#        'delivery': {'id': '309346',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/nom-nom-noodles-1635-eldridge-pkwy-ste-400-houston/309346?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=309346'},
#        'id': '504e277ae4b06b3022818ccc',
#        'location': {'address': '1635 Eldridge Pkwy Ste 400',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4871,
#         'formattedAddress': ['1635 Eldridge Pkwy Ste 400',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.753576720289736,
#           'lng': -95.62464204280427}],
#         'lat': 29.753576720289736,
#         'lng': -95.62464204280427,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'Nom Nom Noodles',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4da7326504377705c3095c86-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/mexican_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c1941735',
#          'name': 'Mexican Restaurant',
#          'pluralName': 'Mexican Restaurants',
#          'primary': True,
#          'shortName': 'Mexican'}],
#        'id': '4da7326504377705c3095c86',
#        'location': {'address': '17754 Katy Fwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'Barker Cypress Rd',
#         'distance': 2716,
#         'formattedAddress': ['17754 Katy Fwy (Barker Cypress Rd)',
#          'Houston, TX 77094',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.78594386537249,
#           'lng': -95.68624292855417}],
#         'lat': 29.78594386537249,
#         'lng': -95.68624292855417,
#         'postalCode': '77094',
#         'state': 'TX'},
#        'name': 'El  Rancho Mexican Restaurant',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b55af21f964a520bfeb27e3-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4b55af21f964a520bfeb27e3',
#        'location': {'address': '15405 Katy Fwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 465,
#         'formattedAddress': ['15405 Katy Fwy',
#          'Houston, TX 77094',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.783724885997472,
#           'lng': -95.65431674376352}],
#         'lat': 29.783724885997472,
#         'lng': -95.65431674376352,
#         'postalCode': '77094',
#         'state': 'TX'},
#        'name': 'Hyatt House Houston/Energy Corridor',
#        'photos': {'count': 0, 'groups': []}}},
# ...
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'primary': True,
#          'shortName': 'Furniture / Home'}],
#        'id': '4b8ad8f3f964a5200f8532e3',
#        'location': {'address': '16555 Park Row',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1201,
#         'formattedAddress': ['16555 Park Row',
#          'Houston, TX 77084',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.78905,
#           'lng': -95.67015}],
#         'lat': 29.78905,
#         'lng': -95.67015,
#         'postalCode': '77084',
#         'state': 'TX'},
#        'name': 'Sears Parts & Repair Center',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-503fdcf5e4b072dc952a440e-88',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'primary': True,
#          'shortName': 'Bubble Tea'}],
#        'id': '503fdcf5e4b072dc952a440e',
#        'location': {'address': '1560 Eldridge Pkwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4441,
#         'formattedAddress': ['1560 Eldridge Pkwy',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.756514977395067,
#           'lng': -95.6275357586359}],
#         'lat': 29.756514977395067,
#         'lng': -95.6275357586359,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'Bubble Tea House',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cbca6864495721e76c25b7a-89',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d126941735',
#          'name': 'Government Building',
#          'pluralName': 'Government Buildings',
#          'primary': True,
#          'shortName': 'Government'}],
#        'id': '4cbca6864495721e76c25b7a',
#        'location': {'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 3736,
#         'formattedAddress': ['Houston, TX 77084', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.816188805249606,
#           'lng': -95.64054906732848}],
#         'lat': 29.816188805249606,
#         'lng': -95.64054906732848,
#         'postalCode': '77084',
#         'state': 'TX'},
#        'name': 'Bear Creek Community Center',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dd2bf2d1f6ef5f6ccdc3790-90',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d122951735',
#          'name': 'Electronics Store',
#          'pluralName': 'Electronics Stores',
#          'primary': True,
#          'shortName': 'Electronics'}],
#        'id': '4dd2bf2d1f6ef5f6ccdc3790',
#        'location': {'address': '1000 Hwy 6, Ste 1200',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 1050,
#         'formattedAddress': ['1000 Hwy 6, Ste 1200',
#          'Houston, TX 77082',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.784741872139623,
#           'lng': -95.64740482413997}],
#         'lat': 29.784741872139623,
#         'lng': -95.64740482413997,
#         'postalCode': '77082',
#         'state': 'TX'},
#        'name': 'Sears',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '161212518'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd5c6869649ce725aa8511d-91',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4bd5c6869649ce725aa8511d',
#        'location': {'address': '15155 Katy Fwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 809,
#         'formattedAddress': ['15155 Katy Fwy',
#          'Houston, TX 77094',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.783220688326068,
#           'lng': -95.65052730919263}],
#         'lat': 29.783220688326068,
#         'lng': -95.65052730919263,
#         'postalCode': '77094',
#         'state': 'TX'},
#        'name': 'TownePlace Suites Houston I-10 West/Energy Corridor',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33343602'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4cd603e7fb595481d0f8e150-92',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'primary': True,
#          'shortName': 'Hotel'}],
#        'id': '4cd603e7fb595481d0f8e150',
#        'location': {'address': '2451 Shadow View Lane',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4864,
#         'formattedAddress': ['2451 Shadow View Lane',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75733,
#           'lng': -95.62042}],
#         'lat': 29.75733,
#         'lng': -95.62042,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'La Quinta Inn & Suites Houston Energy Corridor',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-592b34f5d0a1495f697715e2-93',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gas_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d113951735',
#          'name': 'Gas Station',
#          'pluralName': 'Gas Stations',
#          'primary': True,
#          'shortName': 'Gas Station'}],
#        'id': '592b34f5d0a1495f697715e2',
#        'location': {'address': '3003 Barker Cypress Rd',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'Morton Rd',
#         'distance': 4059,
#         'formattedAddress': ['3003 Barker Cypress Rd (Morton Rd)',
#          'Houston, TX 77084',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.812546,
#           'lng': -95.687289}],
#         'lat': 29.812546,
#         'lng': -95.687289,
#         'postalCode': '77084',
#         'state': 'TX'},
#        'name': 'Circle K',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d0e73695c816ea8314d7d20-94',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '4d0e73695c816ea8314d7d20',
#        'location': {'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4241,
#         'formattedAddress': ['Houston, TX 77077', 'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.760276106828773,
#           'lng': -95.62605070054006}],
#         'lat': 29.760276106828773,
#         'lng': -95.62605070054006,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': "Foody's Gourmet",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bcf9375046076b014a46e71-95',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burrito_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d153941735',
#          'name': 'Burrito Place',
#          'pluralName': 'Burrito Places',
#          'primary': True,
#          'shortName': 'Burritos'}],
#        'delivery': {'id': '690211',
#         'provider': {'icon': {'name': '/delivery_provider_grubhub_20180129.png',
#           'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50]},
#          'name': 'grubhub'},
#         'url': 'https://www.grubhub.com/restaurant/bullritos-1635-eldridge-pkwy-ste-600-houston/690211?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=690211'},
#        'id': '4bcf9375046076b014a46e71',
#        'location': {'address': '1635 Eldridge Pkwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'crossStreet': 'Briar Forest',
#         'distance': 4895,
#         'formattedAddress': ['1635 Eldridge Pkwy (Briar Forest)',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.75329785001458,
#           'lng': -95.62463185351679}],
#         'lat': 29.75329785001458,
#         'lng': -95.62463185351679,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'Bullritos',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4f1e20131e17ededccf54c42-96',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/friedchicken_',
#           'suffix': '.png'},
#          'id': '4d4ae6fc7a7b7dea34424761',
#          'name': 'Fried Chicken Joint',
#          'pluralName': 'Fried Chicken Joints',
#          'primary': True,
#          'shortName': 'Fried Chicken'}],
#        'id': '4f1e20131e17ededccf54c42',
#        'location': {'address': '1585 Highway 6 S',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 3621,
#         'formattedAddress': ['1585 Highway 6 S',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.756226135049936,
#           'lng': -95.64380540033565}],
#         'lat': 29.756226135049936,
#         'lng': -95.64380540033565,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': "Church's Chicken",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c53046b2543a593746a4986-97',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/thai_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d149941735',
#          'name': 'Thai Restaurant',
#          'pluralName': 'Thai Restaurants',
#          'primary': True,
#          'shortName': 'Thai'}],
#        'id': '4c53046b2543a593746a4986',
#        'location': {'address': '1420 Eldridge Pkwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4262,
#         'formattedAddress': ['1420 Eldridge Pkwy',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.759969621086384,
#           'lng': -95.62609121049347}],
#         'lat': 29.759969621086384,
#         'lng': -95.62609121049347,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'Naam Khao Thai Restaurant & Bar',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '357055159'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd8ef4a11dcc9288b7cf833-98',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/gym_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d175941735',
#          'name': 'Gym / Fitness Center',
#          'pluralName': 'Gyms or Fitness Centers',
#          'primary': True,
#          'shortName': 'Gym / Fitness'}],
#        'id': '4bd8ef4a11dcc9288b7cf833',
#        'location': {'address': '17115 Clay Rd',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4952,
#         'formattedAddress': ['17115 Clay Rd',
#          'Houston, TX 77084',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.83074858748739,
#           'lng': -95.65993411880503}],
#         'lat': 29.83074858748739,
#         'lng': -95.65993411880503,
#         'postalCode': '77084',
#         'state': 'TX'},
#        'name': 'West Houston Indoor Soccer',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c600d2123e303bb4ad37407-99',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pharmacy_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f951735',
#          'name': 'Pharmacy',
#          'pluralName': 'Pharmacies',
#          'primary': True,
#          'shortName': 'Pharmacy'}],
#        'id': '4c600d2123e303bb4ad37407',
#        'location': {'address': '1506 Eldridge Pkwy',
#         'cc': 'US',
#         'city': 'Houston',
#         'country': 'United States',
#         'distance': 4545,
#         'formattedAddress': ['1506 Eldridge Pkwy',
#          'Houston, TX 77077',
#          'United States'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 29.756609596919997,
#           'lng': -95.62581558962847}],
#         'lat': 29.756609596919997,
#         'lng': -95.62581558962847,
#         'postalCode': '77077',
#         'state': 'TX'},
#        'name': 'Walgreens',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Houston',
#   'headerLocation': 'Houston',
#   'headerLocationGranularity': 'city',
#   'suggestedBounds': {'ne': {'lat': 29.831290545000044,
#     'lng': -95.60637223174255},
#    'sw': {'lat': 29.741290454999955, 'lng': -95.70987916825744}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'},
#     {'key': 'price', 'name': '$-$$$$'}],
#    'header': 'Tap to show:'},
#   'totalResults': 129}}

# %%
# Let's now extract the categories of the venues
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
SGnearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
SGnearby_venues =SGnearby_venues.loc[:, filtered_columns]

# filter the category for each row
SGnearby_venues['venue.categories'] = SGnearby_venues.apply(get_category_type, axis=1)

# clean columns
SGnearby_venues.columns = [col.split(".")[-1] for col in SGnearby_venues.columns]

SGnearby_venues.head(20)
# Out:
#                                                  name            categories  \
# 0                                             Topgolf    Golf Driving Range
# 1                                  Brother's Pizzeria           Pizza Place
# 2                             Watson's House of Ale's                   Pub
# 3                    Lupe Tortilla Mexican Restaurant    Mexican Restaurant
# 4                              North China Restaurant    Chinese Restaurant
# 5                                              Salata           Salad Place
# 6                    Christian's Tailgate Bar & Grill            Sports Bar
# 7                       SpringHill Suites by Marriott                 Hotel
# 8                                Annam Indian Cuisine     Indian Restaurant
# 9   Fairfield Inn & Suites Houston I-10 West/Energ...                 Hotel
# 10                                      Freddy's Cafe                  Café
# 11                                        Umami Sushi      Sushi Restaurant
# 12                                        Dairy Queen  Fast Food Restaurant
# 13                                 Terry Hershey Park                  Park
# 14                           Terry Hershey Bike Trail    Athletics & Sports
# 15                               Bill Archer Dog Park               Dog Run
# 16                          Tony's Mexican Restaurant    Mexican Restaurant
# 17                                          Starbucks           Coffee Shop
# 18                         Kolache Factory - Park Row                Bakery
# 19                             LaQuinta Inns & Suites                 Hotel
#
#           lat        lng
# 0   29.786743 -95.650050
# 1   29.786889 -95.645525
# 2   29.782844 -95.643579
# 3   29.782903 -95.643100
# 4   29.783944 -95.642419
# 5   29.783908 -95.641992
# 6   29.786865 -95.644110
# 7   29.787306 -95.658506
# 8   29.786948 -95.645506
# 9   29.783947 -95.650437
# 10  29.786057 -95.675380
# 11  29.787573 -95.645339
# 12  29.776409 -95.643871
# 13  29.779138 -95.623096
# 14  29.780618 -95.624487
# 15  29.817540 -95.647513
# 16  29.786049 -95.684353
# 17  29.775286 -95.643470
# 18  29.789360 -95.658007
# 19  29.783666 -95.651461

# %% [markdown]
# Let us now generate a map of Houstons Energy Corridor and nearby venues

# %%
# create map of Houston's Energy Corridor using latitude and longitude values
map_sg = folium.Map(location=[latitude, longitude], zoom_start=14)

# add markers to map
for lat, lng, label in zip(SGnearby_venues['lat'], SGnearby_venues['lng'], SGnearby_venues['name']):
    label = folium.Popup(label, parse_html=True)
    folium.RegularPolygonMarker(
        [lat, lng],
        number_of_sides=4,
        radius=10,
        popup=label,
        color='blue',
        fill_color='#0f0f0f',
        fill_opacity=0.7,
    ).add_to(map_sg)  
    
map_sg
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Count the types of venues in each category to understand what is the current competition

# %%
SGnearby_venues['categories'].value_counts()
# Out:
# Hotel                        9
# Mexican Restaurant           6
# Sandwich Place               5
# Burger Joint                 4
# Coffee Shop                  4
# Cajun / Creole Restaurant    3
# Fast Food Restaurant         3
# Park                         3
# Vietnamese Restaurant        3
# Bakery                       3
# Gym                          2
# Gym / Fitness Center         2
# Mediterranean Restaurant     2
# Café                         2
# Fried Chicken Joint          2
# Pharmacy                     2
# Sushi Restaurant             2
# Chinese Restaurant           2
# Pub                          2
# French Restaurant            2
# Spa                          2
# Dog Run                      1
# Furniture / Home Store       1
# Rental Car Location          1
# Trail                        1
# Golf Driving Range           1
# Health & Beauty Service      1
# Sports Bar                   1
# Athletics & Sports           1
# Tex-Mex Restaurant           1
# New American Restaurant      1
# Salad Place                  1
# Burrito Place                1
# Asian Restaurant             1
# Diner                        1
# Korean Restaurant            1
# Supplement Shop              1
# Bank                         1
# Electronics Store            1
# Salon / Barbershop           1
# Cupcake Shop                 1
# American Restaurant          1
# Gas Station                  1
# Pizza Place                  1
# Government Building          1
# Smoothie Shop                1
# Grocery Store                1
# Breakfast Spot               1
# Indian Restaurant            1
# Convenience Store            1
# Italian Restaurant           1
# Golf Course                  1
# Thai Restaurant              1
# Japanese Restaurant          1
# Bubble Tea Shop              1
# Gift Shop                    1
# Name: categories, dtype: int64

# %% [markdown]
# Count the names of venues (this time) to understand what franchises already exist in the area

# %%
SGnearby_venues['name'].value_counts()
# Out:
# Starbucks                                                   4
# Smashburger                                                 2
# Chick-fil-A                                                 2
# SUBWAY                                                      2
# Carmelo's Restaurant                                        1
# Ninfas                                                      1
# Hyatt House Houston/Energy Corridor                         1
# Pho & Crab Restaurant                                       1
# Smallcakes                                                  1
# Chipotle Mexican Grill                                      1
# Freddy's Frozen Custard & Steakburgers                      1
# ConocoPhillips Gym                                          1
# Bear Creek Community Center                                 1
# Cafe Benedicte                                              1
# Cracker Barrel Old Country Store                            1
# Church's Chicken                                            1
# Walgreens                                                   1
# SpringHill Suites by Marriott                               1
# Burger Tex Grill                                            1
# Dairy Queen                                                 1
# La Quinta Inn & Suites Houston Energy Corridor              1
# Naam Khao Thai Restaurant & Bar                             1
# BB's Tex-Orleans Cooking!                                   1
# Petit Cafe                                                  1
# El  Rancho Mexican Restaurant                               1
# Pine Forest Country Club                                    1
# Foody's Gourmet                                             1
# Freddy's Cafe                                               1
# Clay's Restaurant                                           1
# West Houston Indoor Soccer                                  1
# LA Fisherman                                                1
# Josephine's Day Spa and Salon (Energy Corridor)             1
# Kroger                                                      1
# Fairfield Inn & Suites Houston I-10 West/Energy Corridor    1
# Bill Archer Dog Park                                        1
# European Wax Center                                         1
# Smoothie King                                               1
# Terry Hershey Park                                          1
# CVS pharmacy                                                1
# Tulipo Nails & Spa                                          1
# Topgolf                                                     1
# Aka Japanese Cuisine                                        1
# Lucky's Pub West                                            1
# Kolache Factory - Park Row                                  1
# Pecan Creek Grille                                          1
# TownePlace Suites Houston I-10 West/Energy Corridor         1
# Bullritos                                                   1
# Corner Store                                                1
# Brother's Pizzeria                                          1
# Tony's Mexican Restaurant                                   1
# Cullen Park Wooded Trail RUN                                1
# Bamboo Garden                                               1
# Potbelly Sandwich Shop                                      1
# LA Fitness                                                  1
# Houston Marriott Energy Corridor                            1
# Sears Parts & Repair Center                                 1
# LaQuinta Inns & Suites                                      1
# Watson's House of Ale's                                     1
# Beans Cafe                                                  1
# Bubble Tea House                                            1
# Vellisimo salon & spa                                       1
# Pho Tan An                                                  1
# Omni Houston Hotel at Westside                              1
# Nom Nom Noodles                                             1
# Christian's Tailgate Bar & Grill                            1
# Which Wich? Superior Sandwiches                             1
# Matsu Sushi Bar                                             1
# Popeye's Louisiana Kitchen                                  1
# La Hacienda                                                 1
# Vertskebap                                                  1
# AMLI Fitness Center                                         1
# Jersey Mike's Subs                                          1
# Hertz                                                       1
# North China Restaurant                                      1
# Sears                                                       1
# Lupe Tortilla Mexican Restaurant                            1
# la Madeleine French Bakery & Café Parkway Village           1
# Corner Bakery Cafe                                          1
# Umami Sushi                                                 1
# Le Mistral                                                  1
# Annam Indian Cuisine                                        1
# Trudy's Hallmark #5                                         1
# Cullen Park Phase IV                                        1
# GNC                                                         1
# Raising Cane's Chicken Fingers                              1
# Chili's Grill & Bar                                         1
# Terry Hershey Bike Trail                                    1
# Cullen Park                                                 1
# Rattan Pan-Asian Bistro                                     1
# Kimchi Korean Cafe                                          1
# Salata                                                      1
# Chase Bank                                                  1
# Circle K                                                    1
# Holiday Inn Hou Energy Corridor Eldridge                    1
# Name: name, dtype: int64

# %%
SGnearby_venues['name']
# Out:
# 0                                               Topgolf
# 1                                    Brother's Pizzeria
# 2                               Watson's House of Ale's
# 3                      Lupe Tortilla Mexican Restaurant
# 4                                North China Restaurant
# 5                                                Salata
# 6                      Christian's Tailgate Bar & Grill
# 7                         SpringHill Suites by Marriott
# 8                                  Annam Indian Cuisine
# 9     Fairfield Inn & Suites Houston I-10 West/Energ...
# 10                                        Freddy's Cafe
# 11                                          Umami Sushi
# 12                                          Dairy Queen
# 13                                   Terry Hershey Park
# 14                             Terry Hershey Bike Trail
# 15                                 Bill Archer Dog Park
# 16                            Tony's Mexican Restaurant
# 17                                            Starbucks
# 18                           Kolache Factory - Park Row
# 19                               LaQuinta Inns & Suites
# 20      Josephine's Day Spa and Salon (Energy Corridor)
# 21                                           Beans Cafe
# 22                               Chipotle Mexican Grill
# 23                                        Smoothie King
# 24                              Rattan Pan-Asian Bistro
# 25                                          Chick-fil-A
# 26    la Madeleine French Bakery & Café Parkway Village
# 27                                           Pho Tan An
# 28                            BB's Tex-Orleans Cooking!
# 29                                         LA Fisherman
# 30                                          Chick-fil-A
# 31                                       Cafe Benedicte
# 32                                 Cullen Park Phase IV
# 33                                            Starbucks
# 34                                Pho & Crab Restaurant
# 35                           Popeye's Louisiana Kitchen
# 36                                      Nom Nom Noodles
# 37                        El  Rancho Mexican Restaurant
# 38                  Hyatt House Houston/Energy Corridor
# 39                     Cracker Barrel Old Country Store
# 40                                               Kroger
# 41                             Pine Forest Country Club
# 42                                               SUBWAY
# 43                                   Tulipo Nails & Spa
# 44                                   ConocoPhillips Gym
# 45                       Raising Cane's Chicken Fingers
# 46                                         CVS pharmacy
# 47                                          Cullen Park
# 48             Holiday Inn Hou Energy Corridor Eldridge
# 49                                           Chase Bank
# 50                                          La Hacienda
# 51                       Omni Houston Hotel at Westside
# 52                                           Le Mistral
# 53                                Vellisimo salon & spa
# 54                                     Lucky's Pub West
# 55               Freddy's Frozen Custard & Steakburgers
# 56                                        Bamboo Garden
# 57                                  European Wax Center
# 58                                               Ninfas
# 59                                               SUBWAY
# 60                                      Matsu Sushi Bar
# 61                                            Starbucks
# 62                                           Petit Cafe
# 63                                 Carmelo's Restaurant
# 64                      Which Wich? Superior Sandwiches
# 65                                   Pecan Creek Grille
# 66                                           LA Fitness
# 67                                          Smashburger
# 68                                           Smallcakes
# 69                                                Hertz
# 70                                     Burger Tex Grill
# 71                                           Vertskebap
# 72                     Houston Marriott Energy Corridor
# 73                                          Smashburger
# 74                               Potbelly Sandwich Shop
# 75                                   Corner Bakery Cafe
# 76                                    Clay's Restaurant
# 77                         Cullen Park Wooded Trail RUN
# 78                                   Kimchi Korean Cafe
# 79                                  Chili's Grill & Bar
# 80                                         Corner Store
# 81                                  AMLI Fitness Center
# 82                                  Trudy's Hallmark #5
# 83                                                  GNC
# 84                                 Aka Japanese Cuisine
# 85                                   Jersey Mike's Subs
# 86                                            Starbucks
# 87                          Sears Parts & Repair Center
# 88                                     Bubble Tea House
# 89                          Bear Creek Community Center
# 90                                                Sears
# 91    TownePlace Suites Houston I-10 West/Energy Cor...
# 92       La Quinta Inn & Suites Houston Energy Corridor
# 93                                             Circle K
# 94                                      Foody's Gourmet
# 95                                            Bullritos
# 96                                     Church's Chicken
# 97                      Naam Khao Thai Restaurant & Bar
# 98                           West Houston Indoor Soccer
# 99                                            Walgreens
# Name: name, dtype: object
